# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import requests # Getting Webpage content
from bs4 import BeautifulSoup as bs # Scraping webpages
import matplotlib.pyplot as plt # Visualization
import matplotlib.style as style # For styling plots
from matplotlib import pyplot as mp # For Saving plots as images
import json
import nltk
nltk.download()

# For displaying plots in jupyter notebook
# %matplotlib inline 

style.use('fivethirtyeight') # matplotlib Style
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q

# %% [markdown]
# ###Testing

# %%
#"EIN":"562618866","TaxPeriod":"201512","DLN":"93491316008226","FormType":"990PF","URL":"https://s3.amazonaws.com/irs-form-990/201623169349100822_public.xml","OrganizationName":"BILL AND MELINDA GATES FOUNDATION","SubmittedOn":"2017-03-30","ObjectId":"201623169349100822","LastUpdated":"2017-04-10T21:32:14"}
#https://s3.amazonaws.com/irs-form-990/201941489349100000_public.xml

test_EIN = '562618866'
test_990url = ''
for entry in data2019['Filings2019']:
  if entry['EIN'] == test_EIN:
    test_990url = entry['URL']
    break

test_response = requests.get(test_990url)
test_response.status_code

# %%
soup = bs(test_response.content, 'html.parser')
f = open('test_990.txt', 'w')
f.write(str(soup))
f.close()

# %% [markdown]
# #Full foundation list

# %%
full_foundation_list = pd.read_csv('UT Full Foundation List .csv')
full_foundation_list.head()

full_foundation_list=full_foundation_list.astype(str)

# %% [markdown]
# ##2020

# %%
# Using requests module for downloading webpage content
response2020 = requests.get('https://s3.amazonaws.com/irs-form-990/index_2020.json')
# Getting status of the request
# 200 status code means our request was successful
# 404 status code means that the resource you were looking for was not found
response2020.status_code
# Out:
# 200

# %%
# Parsing html data using BeautifulSoup
soup2020 = bs(response2020.content, 'html.parser')

# %%
#Saving 990 index files as txt files for 990 returns 2020

f=open('index_2020.txt', 'w')
f.write(str(soup2020))
f.close()

# %%
#Saving summaries of 990 files (from index files) 2020
data_2020=''
summary_2020=''
with open('index_2020.txt') as json_file: 
    data_2020 = json.load(json_file)
summary_2020 = data_2020['Filings2020']
print(len(summary_2020))
# Out:
# 333722

# %%
print(summary_2020[0])
# Out:
# {'EIN': '383003703', 'TaxPeriod': '202005', 'DLN': '93492211008030', 'FormType': '990EZ', 'URL': 'https://s3.amazonaws.com/irs-form-990/202032119349200803_public.xml', 'OrganizationName': 'LABOR MANAGEMENT COOPERATION FUND', 'SubmittedOn': '2020-11-24', 'ObjectId': '202032119349200803', 'LastUpdated': '2021-01-29T00:12:26'}

# %%
#Declaring variables (Data to be collected after matching with full list)

ObjectId = []
EIN = []
DLN = []
OrganizationName = []
URL = []

unmatched = []

# %%
index = dict()

for entry in data_2020['Filings2020']:
  name = entry['OrganizationName'].lower()
  index[name] = entry

# %%
matched = dict()
unmatched = []

for row in full_foundation_list['NAME']:
  row = row.lower()
  keys = index.keys()
  if row in keys:
    matched[row] = index[row]
  else:
    unmatched.append(row)

# %%
print(unmatched)
# Out:
# ['12th man foundation', '2a foundation', '4girls foundation inc.', '4girls foundation incorporated', '7th generation foundation', '80-20 foundation', 'a foundation for contemporary art art pace', 'a g foundation', 'a. james & alice b. clark foundation', 'a. w. riterfamily foundation', 'a.i. and manet schepps foundation', 'a.i. and manet schepps foundation inc.', 'aaaa foundation inc.', 'aatcc', 'abbott and leslie sprague family foundation', 'abe zale foundation', 'abim foundation', 'academy of nutrition & dietetics foundation', 'accesslex institute', 'achelis & bodman foundations', 'aci foundation', 'aclu foundation of texas', 'adam f & celia staperfene charitable fund', 'adams charitable foundation inc.', 'adelson medical research foundation', 'adolph coors foundation', 'advertising education foundation of houston', 'aetna foundation inc.', 'agee family foundation', 'aggregates foundation for tech rsrch & educ', 'aging mind foundation', 'agnes marshall walker foundation', 'ahetems', 'albert and ethel herzstein charitable fdn.', 'albert w. and clemmie a. caster foundation', 'alcoholic beverage medical research fdn.', 'alec rhodes foundation', 'alex and kim smith family foundation', 'alexia foundation', 'alfa foundation', 'alfred p. sloan foundation', 'alfred t. stanley foundation', 'alice c. tyler perpetual trust', 'alice kleberg reynolds foundation', 'alice taylor gray foundation', 'alice v. & dave h. morris memorial fund', 'all american football fnd & hall of honor inc', 'allan c. and gloria g. king foundation', 'allied jewish federation of colorado', 'alpha-1 foundation', 'alphawood foundation', 'alternative house', 'alturas foundation', 'alvin and helene eicoff foundation', "alzheimer's drug discovery foundation", 'amado & j.b. pena art has heart foundation', 'amarillo area foundation', 'amer. assoc. of textile chemists & colorists', 'american assembly of men in nursing foundatio', 'american asthma foundation', 'american cancer research center & foundation', 'american cancer research center and foundatio', 'american century investments foundation', 'american clean skies foundation inc.', 'american fdn. for pharmaceutical education', 'american federation for aging research', 'american foundation for aids research', 'american foundation for pharmaceutical educat', 'american heritage education foundation inc.', 'american honda foundation', 'american institute of physics', 'american land foundation', 'american legacy foundation', "american nurses' foundation", 'american psychological foundation', 'american scandinavian foundation', 'american society of health-system pharmacists', 'american speech language hearing foundation', 'american water works association research fdn', 'amherst foundation', 'amon g. carter foundation', 'amy & tom ryan family fund', 'andreasen foundation', 'andy warhol foundation for the visual arts', 'ann lents and j. david heaney foundation', 'anne and c. w. duncan jr. foundation', 'anne and don fizer foundation', 'anne noggle foundation', 'anthem foundation', 'aon foundation', 'arbor day foundation', 'arcus foundation', 'ardon and iris moore foundation', 'argyle foundation', 'arnhold foundation', 'arnold & mabel beckman foundation', 'arnold and augusta newman foundation', 'arnold and marie schwartz fund', 'aron and anaruth gordon foundation', 'aron s. & anaruth p. gordon foundation', 'around the table foundation', 'art + feminism inc.', 'arte ba foundation', 'arthur & joyce schechter philanthropic fund', 'arts connection foundation', 'asid foundation', 'asmara foundation', 'asne foundation', 'aubrey smith family foundation', 'august foundation inc.', 'austin board of realtors foundation', 'austin center for photography inc', 'austin chapter of jack and jill of america', 'austin child guidance', 'austin community foundation', 'austin community foundation bnsw fund', 'austin community foundation msdf giving fund', 'austin ed fund', 'austin foundation for architecture', 'austin pi beta phi foundation', 'au ...

# %%
print(len(matched.keys()))
# Out:
# 330

# %%
print(json.dumps(matched, indent=4))
# Out:
# {
#     "a glimmer of hope foundation": {
#         "EIN": "311758218",
#         "TaxPeriod": "201812",
#         "DLN": "93491316015329",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201

#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201923199349305857_public.xml",
#         "OrganizationName": "COMMUNITY FOUNDATION OF WESTERN NEVADA",
#         "SubmittedOn": "2020-01-24",
#         "ObjectId": "201923199349305857",
#         "LastUpdated": "2020-07-28T16:00:13"
#     },
#     "construction law foundation of texas": {
#         "EIN": "800894777",
#         "TaxPeriod": "201812",
#         "DLN": "93493319035629",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201923199349303562_public.xml",
#         "OrganizationName": "CONSTRUCTION LAW FOUNDATION OF TEXAS",
#         "SubmittedOn": "2020-01-24",
#         "ObjectId": "201923199349303562",
#         "LastUpdated": "2020-07-28T16:00:13"
#     },
#     "core foundation": {
#         "EIN": "363991833",
#         "TaxPeriod": "201906",
#         "DLN": "93493022014000",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/202000229349301400_public.xml",
#         "OrganizationName": "CORE FOUNDATION",
#         "SubmittedOn": "2020-11-18",
#         "ObjectId": "202000229349301400",
#         "LastUpdated": "2021-01-29T00:12:26"
#     },
#     "create foundation": {
#         "EIN": "262588619",
#         "TaxPeriod": "201906",
#         "DLN": "93493318039509",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201903189349303950_public.xml",
#         "OrganizationName": "CREATE FOUNDATION",
#         "SubmittedOn": "2020-01-27",
#         "ObjectId": "201903189349303950",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "crow family foundation inc": {
#         "EIN": "752721699",
#         "TaxPeriod": "201812",
#         "DLN": "93491319022099",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943199349102209_public.xml",
#         "OrganizationName": "CROW FAMILY FOUNDATION INC",
#         "SubmittedOn": "2020-01-23",
#         "ObjectId": "201943199349102209",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "cullen trust for higher education": {
#         "EIN": "741999641",
#         "TaxPeriod": "201812",
#         "DLN": "93493007002450",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/202000079349300245_public.xml",
#         "OrganizationName": "CULLEN TRUST FOR HIGHER EDUCATION",
#         "SubmittedOn": "2020-09-22",
#         "ObjectId": "202000079349300245",
#         "LastUpdated": "2020-10-21T16:54:13"
#     },
#     "dadiva foundation": {
#         "EIN": "841407002",
#         "TaxPeriod": "201812",
#         "DLN": "93491319017359",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201903199349101735_public.xml",
#         "OrganizationName": "DADIVA FOUNDATION",
#         "SubmittedOn": "2020-01-21",
#         "ObjectId": "201903199349101735",
#         "LastUpdated": "2020-07-28T16:00:13"
#     },
#     "daily family foundation": {
#         "EIN": "626390769",
#         "TaxPeriod": "201812",
#         "DLN": "93491311007239",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201933119349100723_public.xml",
#         "OrganizationName": "DAILY FAMILY FOUNDATION",
#         "SubmittedOn": "2020-01-23",
#         "ObjectId": "201933119349100723",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "dallas county historical foundation": {
#         "EIN": "751914314",
#         "TaxPeriod": "201909",
#         "DLN": "93493163018210",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/202011639349301821_public.xml",
#         "OrganizationName": "DALLAS COUNTY HISTORICAL FOUNDATION",
#         "SubmittedOn": "2020-12-21",
#         "ObjectId": "202011639349301821",
#         "LastUpdated": "2021-01-29T00:12:26"
#     },
#     "david and lucile packard foundation": {
#         "EIN": "942278431",
#         "TaxPeriod": "201812",
#         "DLN": "93491319028779",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201923199349102877_public.xml",
#         "OrganizationName": "DAVID AND LUCILE PACKARD FOUNDATION",
#         "SubmittedOn": "2020-01-27",
#         "ObjectId": "201923199349102877",
#         "LastUpdated": "2020-07-28T16:00:13"
#     },
#     "david and willa grace wynne foundation": {
#         "EIN": "300363741",
#         "TaxPeriod": "201812",
#         "DLN": "93491318037149",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943189349103714_public.xml",
#         "OrganizationName": "DAVID AND WILLA GRACE WYNNE FOUNDATION",
#         "SubmittedOn": "2020-01-28",
#         "ObjectId": "201943189349103714",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "dazzio-gutierrez family foundation": {
#         "EIN": "261818091",
#         "TaxPeriod": "201812",
#         "DLN": "93491318030639",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201933189349103063_public.xml",
#         "OrganizationName": "DAZZIO-GUTIERREZ FAMILY FOUNDATION",
#         "SubmittedOn": "2020-01-21",
#         "ObjectId": "201933189349103063",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "deangelis family foundation": {
#         "EIN": "742955715",
#         "TaxPeriod": "201812",
#         "DLN": "93491317028059",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201903179349102805_public.xml",
#         "OrganizationName": "DEANGELIS FAMILY FOUNDATION",
#         "SubmittedOn": "2020-01-13",
#         "ObjectId": "201903179349102805",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "delta gamma foundation": {
#         "EIN": "316034001",
#         "TaxPeriod": "201906",
#         "DLN": "93493319036989",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201933199349303698_public.xml",
#         "OrganizationName": "DELTA GAMMA FOUNDATION",
#         "SubmittedOn": "2020-02-18",
#         "ObjectId": "201933199349303698",
#         "LastUpdated": "2020-07-28T16:00:13"
#     },
#     "dixon water foundation": {
#         "EIN": "752521176",
#         "TaxPeriod": "201812",
#         "DLN": "93491319003449",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943199349100344_public.xml",
#         "OrganizationName": "DIXON WATER FOUNDATION",
#         "SubmittedOn": "2020-02-03",
#         "ObjectId": "201943199349100344",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "djr trust-foundation": {
#         "EIN": "137148229",
#         "TaxPeriod": "201912",
#         "DLN": "93491245014010",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/202012459349101401_public.xml",
#         "OrganizationName": "DJR TRUST-FOUNDATION",
#         "SubmittedOn": "2020-11-25",
#         "ObjectId": "202012459349101401",
#         "LastUpdated": "2021-01-29T00:12:26"
#     },
#     "doll family foundation": {
#         "EIN": "341725981",
#         "TaxPeriod": "201912",
#         "DLN": "93491108008000",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/202001089349100800_public.xml",
#         "OrganizationName": "DOLL FAMILY FOUNDATION",
#         "SubmittedOn": "2020-12-17",
#         "ObjectId": "202001089349100800",
#         "LastUpdated": "2021-01-29T16:02:12"
#     },
#     "dollar general literacy foundation": {
#         "EIN": "621546736",
#         "TaxPeriod": "201901",
#         "DLN": "93493238011259",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201902389349301125_public.xml",
#         "OrganizationName": "DOLLAR GENERAL LITERACY FOUNDATION",
#         "SubmittedOn": "2020-01-10",
#         "ObjectId": "201902389349301125",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "doris and floyd kimble foundation": {
#         "EIN": "341622273",
#         "TaxPeriod": "201812",
#         "DLN": "93491310008399",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943109349100839_public.xml",
#         "OrganizationName": "DORIS AND FLOYD KIMBLE FOUNDATION",
#         "SubmittedOn": "2020-01-24",
#         "ObjectId": "201943109349100839",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "dorothy richard starling foundation": {
#         "EIN": "746121656",
#         "TaxPeriod": "201812",
#         "DLN": "93491317016579",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201923179349101657_public.xml",
#         "OrganizationName": "DOROTHY RICHARD STARLING FOUNDATION",
#         "SubmittedOn": "2020-02-19",
#         "ObjectId": "201923179349101657",
#         "LastUpdated": "2020-07-28T16:00:13"
#     },
#     "dubose family foundation": {
#         "EIN": "201588677",
#         "TaxPeriod": "201812",
#         "DLN": "93491317020709",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201903179349102070_public.xml",
#         "OrganizationName": "DUBOSE FAMILY FOUNDATION",
#         "SubmittedOn": "2020-01-21",
#         "ObjectId": "201903179349102070",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "eastman foundation": {
#         "EIN": "621614800",
#         "TaxPeriod": "201812",
#         "DLN": "93491319052599",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943199349105259_public.xml",
#         "OrganizationName": "EASTMAN FOUNDATION",
#         "SubmittedOn": "2020-01-23",
#         "ObjectId": "201943199349105259",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "ecmc foundation": {
#         "EIN": "411990628",
#         "TaxPeriod": "201812",
#         "DLN": "93493312031299",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943129349303129_public.xml",
#         "OrganizationName": "ECMC FOUNDATION",
#         "SubmittedOn": "2020-01-03",
#         "ObjectId": "201943129349303129",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "edgemon family foundation": {
#         "EIN": "814713414",
#         "TaxPeriod": "201812",
#         "DLN": "93491318021549",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943189349102154_public.xml",
#         "OrganizationName": "EDGEMON FAMILY FOUNDATION",
#         "SubmittedOn": "2020-01-16",
#         "ObjectId": "201943189349102154",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "embrey family foundation": {
#         "EIN": "200215399",
#         "TaxPeriod": "201812",
#         "DLN": "93491319047319",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201913199349104731_public.xml",
#         "OrganizationName": "EMBREY FAMILY FOUNDATION",
#         "SubmittedOn": "2020-02-19",
#         "ObjectId": "201913199349104731",
#         "LastUpdated": "2020-07-28T16:00:13"
#     },
#     "energy foundation": {
#         "EIN": "943126848",
#         "TaxPeriod": "201812",
#         "DLN": "93493318146699",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943189

#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943109349100229_public.xml",
#         "OrganizationName": "WHITE FAMILY FOUNDATION",
#         "SubmittedOn": "2020-01-24",
#         "ObjectId": "201943109349100229",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "whitehurst foundation": {
#         "EIN": "742833742",
#         "TaxPeriod": "201812",
#         "DLN": "93491315010409",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201903159349101040_public.xml",
#         "OrganizationName": "WHITEHURST FOUNDATION",
#         "SubmittedOn": "2020-02-04",
#         "ObjectId": "201903159349101040",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "william and flora hewlett foundation": {
#         "EIN": "941655673",
#         "TaxPeriod": "201812",
#         "DLN": "93491312012699",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943129349101269_public.xml",
#         "OrganizationName": "WILLIAM AND FLORA HEWLETT FOUNDATION",
#         "SubmittedOn": "2020-01-28",
#         "ObjectId": "201943129349101269",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "willowbrook rotary foundation": {
#         "EIN": "760657633",
#         "TaxPeriod": "202006",
#         "DLN": "93493207002000",
#         "FormType": "990",
#         "URL": "https://s3.amazonaws.com/irs-form-990/202002079349300200_public.xml",
#         "OrganizationName": "WILLOWBROOK ROTARY FOUNDATION",
#         "SubmittedOn": "2020-10-13",
#         "ObjectId": "202002079349300200",
#         "LastUpdated": "2020-10-22T19:07:01"
#     },
#     "woodward family foundation": {
#         "EIN": "367015446",
#         "TaxPeriod": "201812",
#         "DLN": "93491315009209",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201903159349100920_public.xml",
#         "OrganizationName": "WOODWARD FAMILY FOUNDATION",
#         "SubmittedOn": "2020-01-16",
#         "ObjectId": "201903159349100920",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "wright family foundation": {
#         "EIN": "522278319",
#         "TaxPeriod": "201812",
#         "DLN": "93491312001449",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201943129349100144_public.xml",
#         "OrganizationName": "WRIGHT FAMILY FOUNDATION",
#         "SubmittedOn": "2020-01-31",
#         "ObjectId": "201943129349100144",
#         "LastUpdated": "2020-04-07T15:44:01"
#     },
#     "wukasch foundation": {
#         "EIN": "760501629",
#         "TaxPeriod": "201812",
#         "DLN": "93491232001089",
#         "FormType": "990PF",
#         "URL": "https://s3.amazonaws.com/irs-form-990/201932329349100108_public.xml",
#         "OrganizationName": "WUKASCH FOUNDATION",
#         "SubmittedOn": "2020-01-13",
#         "ObjectId": "201932329349100108",
#         "LastUpdated": "2020-04-07T15:44:01"
#     }
# }

# %%
import requests

response = requests.get("https://s3.amazonaws.com/irs-form-990/201913129349100421_public.xml")
print(response.text)
# Out:
# ï»¿<?xml version="1.0" encoding="utf-8"?>
# <Return xmlns="http://www.irs.gov/efile" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.irs.gov/efile" returnVersion="2018v3.1">
#   <ReturnHeader binaryAttachmentCnt="0">
#     <ReturnTs>2019-11-08T11:12:03-06:00</ReturnTs>
#     <TaxPeriodEndDt>2019-06-30</TaxPeriodEndDt>
#     <PreparerFirmGrp>
#       <PreparerFirmEIN>133050313</PreparerFirmEIN>
#       <PreparerFirmName>
#         <BusinessNameLine1Txt>SACKS PRESS &amp; LACHER PC</BusinessNameLine1Txt>
#       </PreparerFirmName>
#       <PreparerUSAddress>
#         <AddressLine1Txt>600 THIRD AVENUE</AddressLine1Txt>
#         <CityNm>NEW YORK</CityNm>
#         <StateAbbreviationCd>NY</StateAbbreviationCd>
#         <ZIPCd>100161901</ZIPCd>
#       </PreparerUSAddress>
#     </PreparerFirmGrp>
#     <ReturnTypeCd>990PF</ReturnTypeCd>
#     <TaxPeriodBeginDt>2018-07-01</TaxPeriodBeginDt>
#     <Filer>
#       <EIN>137204588</EIN>
#       <BusinessName>
#         <BusinessNameLine1Txt>STRYPEMONDE FOUNDATION</BusinessNameLine1Txt>
#       </BusinessName>
#       <BusinessNameControlTxt>STRY</BusinessNameControlTxt>
#       <PhoneNum>2126826640</PhoneNum>
#       <USAddress>
#         <AddressLine1Txt>C/O SACKS 600 THIRD AVE NO 1801</AddressLine1Txt>
#         <CityNm>NEW YORK</CityNm>
#         <StateAbbreviationCd>NY</StateAbbreviationCd>
#         <ZIPCd>10016</ZIPCd>
#       </USAddress>
#     </Filer>
#     <BusinessOfficerGrp>
#       <PersonNm>TITIA HULST</PersonNm>
#       <PersonTitleTxt>PRESIDENT</PersonTitleTxt>
#       <PhoneNum>2126826640</PhoneNum>
#       <SignatureDt>2019-07-09</SignatureDt>
#       <DiscussWithPaidPreparerInd>1</DiscussWithPaidPreparerInd>
#     </BusinessOfficerGrp>
#     <PreparerPersonGrp>
#       <PreparerPersonNm>GARY D LACHER</PreparerPersonNm>
#       <PTIN>P00192831</PTIN>
#       <PhoneNum>2126826640</PhoneNum>
#       <PreparationDt>2019-07-09</PreparationDt>
#     </PreparerPersonGrp>
#     <FilingSecurityInformation>
#       <IPAddress>
#         <IPv4AddressTxt>38.122.224.130</IPv4AddressTxt>
#       </IPAddress>
#       <IPDt>2019-07-09</IPDt>
#       <IPTm>16:45:03</IPTm>
#       <IPTimezoneCd>ED</IPTimezoneCd>
#       <FilingLicenseTypeCd>P</FilingLicenseTypeCd>
#       <AtSubmissionCreationDeviceId>9BE2CBA19EAB42E3AA6A58C583F06FD5835108C0</AtSubmissionCreationDeviceId>
#       <AtSubmissionFilingDeviceId>9AB29866FEBD35FC8AD1B1BE4DBE3C3765EB0F74</AtSubmissionFilingDeviceId>
#     </FilingSecurityInformation>
#     <TaxYr>2018</TaxYr>
#     <BuildTS>2020-03-31 21:24:44Z</BuildTS>
#   </ReturnHeader>
#   <ReturnData documentCnt="8">
#     <IRS990PF documentId="RetDoc1235000001">
#       <Organization501c3ExemptPFInd>X</Organization501c3ExemptPFInd>
#       <FMVAssetsEOYAmt>14007378</FMVAssetsEOYAmt>
#       <MethodOfAccountingCashInd>X</MethodOfAccountingCashInd>
#       <AnalysisOfRevenueAndExpenses>
#         <ScheduleBNotRequiredInd>X</ScheduleBNotRequiredInd>
#         <InterestOnSavRevAndExpnssAmt>606</InterestOnSavRevAndExpnssAmt>
#         <InterestOnSavNetInvstIncmAmt>606</InterestOnSavNetInvstIncmAmt>
#         <DividendsRevAndExpnssAmt>230819</DividendsRevAndExpnssAmt>
#         <DividendsNetInvstIncmAmt>230779</DividendsNetInvstIncmAmt>
#         <NetGainSaleAstRevAndExpnssAmt>-29813</NetGainSaleAstRevAndExpnssAmt>
#         <GrossSalesPriceAmt>875624</GrossSalesPriceAmt>
#         <CapGainNetIncmNetInvstIncmAmt>0</CapGainNetIncmNetInvstIncmAmt>
#         <TotalRevAndExpnssAmt>201612</TotalRevAndExpnssAmt>
#         <TotalNetInvstIncmAmt>231385</TotalNetInvstIncmAmt>
#         <CompOfcrDirTrstRevAndExpnssAmt>0</CompOfcrDirTrstRevAndExpnssAmt>
#         <CompOfcrDirTrstNetInvstIncmAmt>0</CompOfcrDirTrstNetInvstIncmAmt>
#         <CompOfcrDirTrstDsbrsChrtblAmt>0</CompOfcrDirTrstDsbrsChrtblAmt>
#         <AccountingFeesRevAndExpnssAmt referenceDocumentId="RetDoc2002200001">7000</AccountingFeesRevAndExpnssAmt>
#         <AccountingFeesNetInvstIncmAmt>7000</AccountingFeesNetInvstIncmAmt>
#         <AccountingFeesChrtblPrpsAmt>0</AccountingFeesChrtblPrpsAmt>
#         <OtherProfFeesRevAndExpnssAmt referenceDocumentId="RetDoc2002300001">33726</OtherProfFeesRevAndExpnssAmt>
#         <OtherProfFeesNetInvstIncmAmt>33726</OtherProfFeesNetInvstIncmAmt>
#         <OtherProfFeesDsbrsChrtblAmt>0</OtherProfFeesDsbrsChrtblAmt>
#         <InterestRevAndExpnssAmt>23998</InterestRevAndExpnssAmt>
#         <InterestNetInvstIncmAmt>23945</InterestNetInvstIncmAmt>
#         <InterestDsbrsChrtblAmt>0</InterestDsbrsChrtblAmt>
#         <TaxesRevAndExpnssAmt referenceDocumentId="RetDoc2002500001">11300</TaxesRevAndExpnssAmt>
#         <TaxesNetInvstIncmAmt>11300</TaxesNetInvstIncmAmt>
#         <TaxesDsbrsChrtblAmt>0</TaxesDsbrsChrtblAmt>
#         <TravConfMeetingRevAndExpnssAmt>14120</TravConfMeetingRevAndExpnssAmt>
#         <TravConfMeetingNetInvstIncmAmt>0</TravConfMeetingNetInvstIncmAmt>
#         <TravConfMeetingDsbrsChrtblAmt>14120</TravConfMeetingDsbrsChrtblAmt>
#         <OtherExpensesRevAndExpnssAmt referenceDocumentId="RetDoc2003200001">201853</OtherExpensesRevAndExpnssAmt>
#         <OtherExpensesNetInvstIncmAmt>190881</OtherExpensesNetInvstIncmAmt>
#         <OtherExpensesDsbrsChrtblAmt>8500</OtherExpensesDsbrsChrtblAmt>
#         <TotOprExpensesRevAndExpnssAmt>291997</TotOprExpensesRevAndExpnssAmt>
#         <TotOprExpensesNetInvstIncmAmt>266852</TotOprExpensesNetInvstIncmAmt>
#         <TotOprExpensesDsbrsChrtblAmt>22620</TotOprExpensesDsbrsChrtblAmt>
#         <ContriPaidRevAndExpnssAmt>839750</ContriPaidRevAndExpnssAmt>
#         <ContriPaidDsbrsChrtblAmt>839750</ContriPaidDsbrsChrtblAmt>
#         <TotalExpensesRevAndExpnssAmt>1131747</TotalExpensesRevAndExpnssAmt>
#         <TotalExpensesNetInvstIncmAmt>266852</TotalExpensesNetInvstIncmAmt>
#         <TotalExpensesDsbrsChrtblAmt>862370</TotalExpensesDsbrsChrtblAmt>
#         <ExcessRevenueOverExpensesAmt>-930135</ExcessRevenueOverExpensesAmt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#       </AnalysisOfRevenueAndExpenses>
#       <Form990PFBalanceSheetsGrp>
#         <CashBOYAmt>14116</CashBOYAmt>
#         <CashEOYAmt>66538</CashEOYAmt>
#         <CashEOYFMVAmt>66538</CashEOYFMVAmt>
#         <SavAndTempCashInvstBOYAmt>19962</SavAndTempCashInvstBOYAmt>
#         <SavAndTempCashInvstEOYAmt>459735</SavAndTempCashInvstEOYAmt>
#         <SavAndTempCashInvstEOYFMVAmt>459735</SavAndTempCashInvstEOYFMVAmt>
#         <CorporateStockBOYAmt>3736278</CorporateStockBOYAmt>
#         <CorporateStockEOYAmt referenceDocumentId="RetDoc2018900001">3012525</CorporateStockEOYAmt>
#         <CorporateStockEOYFMVAmt>4262887</CorporateStockEOYFMVAmt>
#         <OtherInvestmentsBOYAmt>11050575</OtherInvestmentsBOYAmt>
#         <OtherInvestmentsEOYAmt referenceDocumentId="RetDoc2018100001">9218218</OtherInvestmentsEOYAmt>
#         <OtherInvestmentsEOYFMVAmt>9218218</OtherInvestmentsEOYFMVAmt>
#         <TotalAssetsBOYAmt>14820931</TotalAssetsBOYAmt>
#         <TotalAssetsEOYAmt>12757016</TotalAssetsEOYAmt>
#         <TotalAssetsEOYFMVAmt>14007378</TotalAssetsEOYFMVAmt>
#         <TotalLiabilitiesBOYAmt>0</TotalLiabilitiesBOYAmt>
#         <TotalLiabilitiesEOYAmt>0</TotalLiabilitiesEOYAmt>
#         <OrgDoesNotFollowSFAS117Ind>X</OrgDoesNotFollowSFAS117Ind>
#         <CapitalStockBOYAmt>0</CapitalStockBOYAmt>
#         <CapitalStockEOYAmt>0</CapitalStockEOYAmt>
#         <AdditionalPaidInCapitalBOYAmt>0</AdditionalPaidInCapitalBOYAmt>
#         <AdditionalPaidInCapitalEOYAmt>0</AdditionalPaidInCapitalEOYAmt>
#         <RetainedEarningBOYAmt>14820931</RetainedEarningBOYAmt>
#         <RetainedEarningEOYAmt>12757016</RetainedEarningEOYAmt>
#         <TotNetAstOrFundBalancesBOYAmt>14820931</TotNetAstOrFundBalancesBOYAmt>
#         <TotNetAstOrFundBalancesEOYAmt>12757016</TotNetAstOrFundBalancesEOYAmt>
#         <TotalLiabilitiesNetAstBOYAmt>14820931</TotalLiabilitiesNetAstBOYAmt>
#         <TotalLiabilitiesNetAstEOYAmt>12757016</TotalLiabilitiesNetAstEOYAmt>
#       </Form990PFBalanceSheetsGrp>
#       <ChgInNetAssetsFundBalancesGrp>
#         <TotNetAstOrFundBalancesBOYAmt>14820931</TotNetAstOrFundBalancesBOYAmt>
#         <ExcessRevenueOverExpensesAmt>-930135</ExcessRevenueOverExpensesAmt>
#         <OtherIncreasesAmt>0</OtherIncreasesAmt>
#         <SubtotalAmt>13890796</SubtotalAmt>
#         <OtherDecreasesAmt referenceDocumentId="RetDoc2049800001">1133780</OtherDecreasesAmt>
#         <TotNetAstOrFundBalancesEOYAmt>12757016</TotNetAstOrFundBalancesEOYAmt>
#       </ChgInNetAssetsFundBalancesGrp>
#       <CapGainsLossTxInvstIncmDetail>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>PUBLICLY TRADED SECURITIES</PropertyDesc>
#           <GrossSalesPriceAmt>815572</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>764660</CostOrOtherBasisAmt>
#           <GainOrLossAmt>50912</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>50912</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>K-1 PASS THROUGH NSV EXTENSION</PropertyDesc>
#           <HowAcquiredCd>P</HowAcquiredCd>
#           <CostOrOtherBasisAmt>58800</CostOrOtherBasisAmt>
#           <GainOrLossAmt>-58800</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>-58800</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>K-1 PASS THROUGH BROOKSIDE</PropertyDesc>
#           <HowAcquiredCd>P</HowAcquiredCd>
#           <GrossSalesPriceAmt>49517</GrossSalesPriceAmt>
#           <GainOrLossAmt>49517</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>49517</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>K-1 PASS THROUGH NSV NEW OPPORTUNITIES</PropertyDesc>
#           <HowAcquiredCd>P</HowAcquiredCd>
#           <CostOrOtherBasisAmt>44566</CostOrOtherBasisAmt>
#           <GainOrLossAmt>-44566</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>-44566</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>K-1 PASS THROUGH RAIL SPLITTER FUND</PropertyDesc>
#           <HowAcquiredCd>P</HowAcquiredCd>
#           <GrossSalesPriceAmt>1369</GrossSalesPriceAmt>
#           <GainOrLossAmt>1369</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>1369</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>K-1 PASS THROUGH SC FUNDAMENTAL VALUE FUND</PropertyDesc>
#           <HowAcquiredCd>P</HowAcquiredCd>
#           <CostOrOtherBasisAmt>37411</CostOrOtherBasisAmt>
#           <GainOrLossAmt>-37411</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>-37411</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>K-1 PASS THROUGH BROOKSIDE</PropertyDesc>
#           <HowAcquiredCd>P</HowAcquiredCd>
#           <GrossSalesPriceAmt>9166</GrossSalesPriceAmt>
#           <GainOrLossAmt>9166</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>9166</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapitalGainNetIncomeAmt>-29813</CapitalGainNetIncomeAmt>
#       </CapGainsLossTxInvstIncmDetail>
#       <QlfyUndSect4940eReducedTaxGrp>
#         <LiableSection4942TaxInd>0</LiableSection4942TaxInd>
#         <AdjustedQlfyDistriYr1Amt>1106570</AdjustedQlfyDistriYr1Amt>
#         <NetVlNoncharitableAssetsYr1Amt>15626589</NetVlNoncharitableAssetsYr1Amt>
#         <DistributionYr1Rt>0.070813</DistributionYr1Rt>
#         <AdjustedQlfyDistriYr2Amt>892708</AdjustedQlfyDistriYr2Amt>
#         <NetVlNoncharitableAssetsYr2Amt>16530361</NetVlNoncharitableAssetsYr2Amt>
#         <DistributionYr2Rt>0.054004</DistributionYr2Rt>
#         <AdjustedQlfyDistriYr3Amt>544475</AdjustedQlfyDistriYr3Amt>
#         <NetVlNoncharitableAssetsYr3Amt>16870647</NetVlNoncharitableAssetsYr3Amt>
#         <DistributionYr3Rt>0.032274</DistributionYr3Rt>
#         <AdjustedQlfyDistriYr4Amt>802763</AdjustedQlfyDistriYr4Amt>
#         <NetVlNoncharitableAssetsYr4Amt>16487749</NetVlNoncharitableAssetsYr4Amt>
#         <DistributionYr4Rt>0.048688</DistributionYr4Rt>
#         <AdjustedQlfyDistriYr5Amt>590358</AdjustedQlfyDistriYr5Amt>
#         <NetVlNoncharitableAssetsYr5Amt>15306814</NetVlNoncharitableAssetsYr5Amt>
#         <DistributionYr5Rt>0.038568</DistributionYr5Rt>
#         <TotalDistributionRt>0.244347</TotalDistributionRt>
#         <AverageDistributionRt>0.048869</AverageDistributionRt>
#         <NetVlNoncharitableAssetsAmt>14662301</NetVlNoncharitableAssetsAmt>
#         <AdjNetVlNoncharitableAssetsAmt>716532</AdjNetVlNoncharitableAssetsAmt>
#         <NetInvestmentIncomePctAmt>0</NetInvestmentIncomePctAmt>
#         <AdjNonchrtblNetInvstIncmPctAmt>716532</AdjNonchrtblNetInvstIncmPctAmt>
#         <QualifyingDistributionsAmt>862370</QualifyingDistributionsAmt>
#       </QlfyUndSect4940eReducedTaxGrp>
#       <ExciseTaxBasedOnInvstIncmGrp>
#         <DomesticOrgMeetingSect4940eInd>X</DomesticOrgMeetingSect4940eInd>
#         <InvestmentIncomeExciseTaxAmt>0</InvestmentIncomeExciseTaxAmt>
#         <TaxUnderSection511Amt>0</TaxUnderSection511Amt>
#         <SubtotalAmt>0</SubtotalAmt>
#         <SubtitleATaxAmt>0</SubtitleATaxAmt>
#         <TaxBasedOnInvestmentIncomeAmt>0</TaxBasedOnInvestmentIncomeAmt>
#         <EstimatedPlusOvpmtIncmTxAmt>19224</EstimatedPlusOvpmtIncmTxAmt>
#         <ExtsnRequestIncomeTaxPaidAmt>0</ExtsnRequestIncomeTaxPaidAmt>
#         <BackupWithholdingWithheldAmt>0</BackupWithholdingWithheldAmt>
#         <TotalPaymentsAndCreditsAmt>19224</TotalPaymentsAndCreditsAmt>
#         <EsPenaltyAmt>0</EsPenaltyAmt>
#         <OverpaymentAmt>19224</OverpaymentAmt>
#         <AppliedToESTaxAmt>19224</AppliedToESTaxAmt>
#         <RefundAmt>0</RefundAmt>
#       </ExciseTaxBasedOnInvstIncmGrp>
#       <StatementsRegardingActyGrp>
#         <LegislativePoliticalActyInd>0</LegislativePoliticalActyInd>
#         <MoreThan100SpentInd>0</MoreThan100SpentInd>
#         <Form1120POLFiledInd>0</Form1120POLFiledInd>
#         <Section4955OrganizationTaxAmt>0</Section4955OrganizationTaxAmt>
#         <Section4955ManagersTaxAmt>0</Section4955ManagersTaxAmt>
#         <TaxReimbursedAmt>0</TaxReimbursedAmt>
#         <ActivitiesNotPreviouslyRptInd>0</ActivitiesNotPreviouslyRptInd>
#         <ChangesToArticlesOrBylawsInd>0</ChangesToArticlesOrBylawsInd>
#         <UnrelatedBusIncmOverLimitInd>1</UnrelatedBusIncmOverLimitInd>
#         <Form990TFiledInd>1</Form990TFiledInd>
#         <OrganizationDissolvedEtcInd>0</OrganizationDissolvedEtcInd>
#         <Section508eRqrSatisfiedInd>1</Section508eRqrSatisfiedInd>
#         <AtLeast5000InAssetsInd>1</AtLeast5000InAssetsInd>
#         <OrgReportOrRegisterStateCd>NY</OrgReportOrRegisterStateCd>
#         <Form990PFFiledWithAttyGenInd>1</Form990PFFiledWithAttyGenInd>
#         <PrivateOperatingFoundationInd>0</PrivateOperatingFoundationInd>
#         <NewSubstantialContributorsInd>0</NewSubstantialContributorsInd>
#         <OwnControlledEntityInd>0</OwnControlledEntityInd>
#         <DonorAdvisedFundInd>0</DonorAdvisedFundInd>
#         <ComplyWithPublicInspRqrInd>1</ComplyWithPublicInspRqrInd>
#         <WebsiteAddressTxt>N/A</WebsiteAddressTxt>
#         <IndividualWithBooksNm>SACKS PRESS LACHER PC</IndividualWithBooksNm>
#         <PhoneNum>2126826640</PhoneNum>
#         <LocationOfBooksUSAddress>
#           <AddressLine1Txt>600 THIRD AVE</AddressLine1Txt>
#           <CityNm>NEW YORK</CityNm>
#           <StateAbbreviationCd>NY</StateAbbreviationCd>
#           <ZIPCd>10016</ZIPCd>
#         </LocationOfBooksUSAddress>
#         <ForeignAccountsQuestionInd>0</ForeignAccountsQuestionInd>
#       </StatementsRegardingActyGrp>
#       <StatementsRegardingActy4720Grp>
#         <SaleOrExchDisqualifiedPrsnInd>0</SaleOrExchDisqualifiedPrsnInd>
#         <BrrwOrLendDisqualifiedPrsnInd>0</BrrwOrLendDisqualifiedPrsnInd>
#         <FurnGoodsDisqualifiedPrsnInd>0</FurnGoodsDisqualifiedPrsnInd>
#         <PayCompDisqualifiedPrsnInd>0</PayCompDisqualifiedPrsnInd>
#         <TransferAstDisqualifiedPrsnInd>0</TransferAstDisqualifiedPrsnInd>
#         <PaymentToGovernmentOfficialInd>0</PaymentToGovernmentOfficialInd>
#         <UncorrectedPriorActsInd>0</UncorrectedPriorActsInd>
#         <UndistributedIncomePYInd>0</UndistributedIncomePYInd>
#         <BusinessHoldingsInd>0</BusinessHoldingsInd>
#         <JeopardyInvestmentsInd>0</JeopardyInvestmentsInd>
#         <UncorrectedPYJeopardyInvstInd>0</UncorrectedPYJeopardyInvstInd>
#         <InfluenceLegislationInd>0</InfluenceLegislationInd>
#         <InfluenceElectionInd>0</InfluenceElectionInd>
#         <GrantsToIndividualsInd>0</GrantsToIndividualsInd>
#         <GrantsToOrganizationsInd>0</GrantsToOrganizationsInd>
#         <NoncharitablePurposeInd>0</NoncharitablePurposeInd>
#         <RcvFndsToPayPrsnlBnftCntrctInd>0</RcvFndsToPayPrsnlBnftCntrctInd>
#         <PayPremiumsPrsnlBnftCntrctInd>0</PayPremiumsPrsnlBnftCntrctInd>
#         <ProhibitedTaxShelterTransInd>0</ProhibitedTaxShelterTransInd>
#         <SubjToTaxRmnrtnExPrchtPymtInd>0</SubjToTaxRmnrtnExPrchtPymtInd>
#       </StatementsRegardingActy4720Grp>
#       <OfficerDirTrstKeyEmplInfoGrp>
#         <OfficerDirTrstKeyEmplGrp>
#           <PersonNm>PAUL FRANCIS</PersonNm>
#           <USAddress>
#             <AddressLine1Txt>1384 PARK LANE</AddressLine1Txt>
#             <CityNm>PELHAM MANOR</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10803</ZIPCd>
#           </USAddress>
#           <TitleTxt>VICE PRESIDENT, SECRETARY</TitleTxt>
#           <AverageHrsPerWkDevotedToPosRt>5.00</AverageHrsPerWkDevotedToPosRt>
#           <CompensationAmt>0</CompensationAmt>
#           <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#           <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#         </OfficerDirTrstKeyEmplGrp>
#         <OfficerDirTrstKeyEmplGrp>
#           <PersonNm>TITIA HULST</PersonNm>
#           <USAddress>
#             <AddressLine1Txt>1384 PARK LANE</AddressLine1Txt>
#             <CityNm>PELHAM MANOR</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10803</ZIPCd>
#           </USAddress>
#           <TitleTxt>PRESIDENT</TitleTxt>
#           <AverageHrsPerWkDevotedToPosRt>5.00</AverageHrsPerWkDevotedToPosRt>
#           <CompensationAmt>0</CompensationAmt>
#           <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#           <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#         </OfficerDirTrstKeyEmplGrp>
#         <CompOfHghstPdEmplOrNONETxt>NONE</CompOfHghstPdEmplOrNONETxt>
#         <OtherEmployeePaidOver50kCnt>0</OtherEmployeePaidOver50kCnt>
#         <CompOfHghstPdCntrctOrNONETxt>NONE</CompOfHghstPdCntrctOrNONETxt>
#         <ContractorPaidOver50kCnt>0</ContractorPaidOver50kCnt>
#       </OfficerDirTrstKeyEmplInfoGrp>
#       <SumOfProgramRelatedInvstGrp>
#         <TotalAmt>0</TotalAmt>
#       </SumOfProgramRelatedInvstGrp>
#       <MinimumInvestmentReturnGrp>
#         <AverageMonthlyFMVOfSecAmt>4471044</AverageMonthlyFMVOfSecAmt>
#         <AverageMonthlyCashBalancesAmt>280145</AverageMonthlyCashBalancesAmt>
#         <FMVAllOtherNoncharitableAstAmt>10134396</FMVAllOtherNoncharitableAstAmt>
#         <TotalFMVOfUnusedAssetsAmt>14885585</TotalFMVOfUnusedAssetsAmt>
#         <ReductionClaimedAmt>0</ReductionClaimedAmt>
#         <AcquisitionIndebtednessAmt>0</AcquisitionIndebtednessAmt>
#         <AdjustedTotalFMVOfUnusedAstAmt>14885585</AdjustedTotalFMVOfUnusedAstAmt>
#         <CashDeemedCharitableAmt>223284</CashDeemedCharitableAmt>
#         <NetVlNoncharitableAssetsAmt>14662301</NetVlNoncharitableAssetsAmt>
#         <MinimumInvestmentReturnAmt>733115</MinimumInvestmentReturnAmt>
#       </MinimumInvestmentReturnGrp>
#       <DistributableAmountGrp>
#         <MinimumInvestmentReturnAmt>733115</MinimumInvestmentReturnAmt>
#         <IncomeTaxAmt>828</IncomeTaxAmt>
#         <TotalTaxAmt>828</TotalTaxAmt>
#         <DistributableBeforeAdjAmt>732287</DistributableBeforeAdjAmt>
#         <RecoveriesQualfiedDistriAmt>0</RecoveriesQualfiedDistriAmt>
#         <DistributableBeforeDedAmt>732287</DistributableBeforeDedAmt>
#         <DeductionFromDistributableAmt>0</DeductionFromDistributableAmt>
#         <DistributableAsAdjustedAmt>732287</DistributableAsAdjustedAmt>
#       </DistributableAmountGrp>
#       <QualifyingDistriPartXIIGrp>
#         <ExpensesAndContributionsAmt>862370</ExpensesAndContributionsAmt>
#         <ProgramRelatedInvstTotalAmt>0</ProgramRelatedInvstTotalAmt>
#         <QualifyingDistributionsAmt>862370</QualifyingDistributionsAmt>
#         <PctSect4940eOrgNetInvstIncmAmt>0</PctSect4940eOrgNetInvstIncmAmt>
#         <AdjustedQualifyingDistriAmt>862370</AdjustedQualifyingDistriAmt>
#       </QualifyingDistriPartXIIGrp>
#       <UndistributedIncomeGrp>
#         <DistributableAsAdjustedAmt>732287</DistributableAsAdjustedAmt>
#         <UndistributedIncomePYAmt>0</UndistributedIncomePYAmt>
#         <TotalForPriorYearsAmt>0</TotalForPriorYearsAmt>
#         <ExcessDistributionCyovYr1Amt>228379</ExcessDistributionCyovYr1Amt>
#         <TotalExcessDistributionCyovAmt>228379</TotalExcessDistributionCyovAmt>
#         <QualifyingDistributionsAmt>862370</QualifyingDistributionsAmt>
#         <AppliedToYear1Amt>0</AppliedToYear1Amt>
#         <AppliedToPriorYearsAmt>0</AppliedToPriorYearsAmt>
#         <TreatedAsDistriFromCorpusAmt>0</TreatedAsDistriFromCorpusAmt>
#         <AppliedToCurrentYearAmt>732287</AppliedToCurrentYearAmt>
#         <RemainingDistriFromCorpusAmt>130083</RemainingDistriFromCorpusAmt>
#         <ExcessDistriCyovAppCYCorpusAmt>0</ExcessDistriCyovAppCYCorpusAmt>
#         <ExcessDistributionCyovAppCYAmt>0</ExcessDistributionCyovAppCYAmt>
#         <TotalCorpusAmt>358462</TotalCorpusAmt>
#         <PriorYearUndistributedIncmAmt>0</PriorYearUndistributedIncmAmt>
#         <PriorYearDeficiencyOrTaxAmt>0</PriorYearDeficiencyOrTaxAmt>
#         <Taxable1Amt>0</Taxable1Amt>
#         <Taxable2Amt>0</Taxable2Amt>
#         <UndistributedIncomeCYAmt>0</UndistributedIncomeCYAmt>
#         <CorpusDistri170b1EOr4942g3Amt>0</CorpusDistri170b1EOr4942g3Amt>
#         <ExcessDistriCyovFromYr5Amt>0</ExcessDistriCyovFromYr5Amt>
#         <ExcessDistriCyovToNextYrAmt>358462</ExcessDistriCyovToNextYrAmt>
#         <ExcessFromYear1Amt>228379</ExcessFromYear1Amt>
#         <ExcessFromCurrentYearAmt>130083</ExcessFromCurrentYearAmt>
#       </UndistributedIncomeGrp>
#       <SupplementaryInformationGrp>
#         <ContributingManagerNm>PAUL FRANCIS</ContributingManagerNm>
#         <OnlyContriToPreselectedInd>X</OnlyContriToPreselectedInd>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NORTH HAVEN HISTORICAL SOCIETY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>77 PULPIT HARBOR RD</AddressLine1Txt>
#             <CityNm>NORTH HAVEN</CityNm>
#             <StateAbbreviationCd>ME</StateAbbreviationCd>
#             <ZIPCd>04853</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>250</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>FRIENDS OF PELHAM BAY PARK</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 71</AddressLine1Txt>
#             <CityNm>BRONX</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10464</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>500</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NORTH HAVEN BAPTIST CHURCH</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>4600 36TH AVE NW</AddressLine1Txt>
#             <CityNm>NORMAN</CityNm>
#             <StateAbbreviationCd>OK</StateAbbreviationCd>
#             <ZIPCd>73072</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>500</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NORTH HAVEN CONSERVATION PARTNER</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>12 MAIN STREET</AddressLine1Txt>
#             <CityNm>NORTH HAVEN</CityNm>
#             <StateAbbreviationCd>ME</StateAbbreviationCd>
#             <ZIPCd>04853</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>500</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>ARCHIVES OF AMERICAN ART</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1285 AVENUE OF THE AMERICAS</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10019</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>ART 21</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>133 WEST 25TH STREET 3E</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10001</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>FOSTER PRIDE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>250 W 94TH ST</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10025</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NEW ROCHELLE YMCA</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>50 WEYMAN AVE</AddressLine1Txt>
#             <CityNm>NEW ROCHELLE</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10805</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NEW YORK PHILHARMONIC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>10 LINCOLN CENTER</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10023</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NORTH HAVEN LIBRARY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>33 MAIN ST</AddressLine1Txt>
#             <CityNm>NEW HAVEN</CityNm>
#             <StateAbbreviationCd>ME</StateAbbreviationCd>
#             <ZIPCd>04853</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>OCTOBER MAGAZINE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>350 FIFTH AVENUE</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10118</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>WESTCHESTER CHILDREN'S ASSOCIATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>470 MAMARONECK AVENUE SUITE 304</AddressLine1Txt>
#             <CityNm>WHITE PLAINS</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10605</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CENTER FOR AN URBAN FUTURE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>120 WALL ST</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10005</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NORTH HAVEN FOUNDATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>10 SCHOOL STREET</AddressLine1Txt>
#             <CityNm>ROCKLAND</CityNm>
#             <StateAbbreviationCd>ME</StateAbbreviationCd>
#             <ZIPCd>04841</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>1500</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>FRIENDS OF PELHAM PUBLIC LIBRARY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>248 MONTEREY AVE</AddressLine1Txt>
#             <CityNm>PELHAM</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10803</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>2500</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>THE WOOSTER GROUP</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>33 WOOSTER STREET 2</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10013</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>4000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NEW YORK PUBLIC RADIO</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>160 VARICK STREET 8TH FLOOR</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10013</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NORTH HAVEN SUSTAINABLE HOUSING</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>148 CRABTREE POINT ROAD</AddressLine1Txt>
#             <CityNm>NORTH HAVEN</CityNm>
#             <StateAbbreviationCd>ME</StateAbbreviationCd>
#             <ZIPCd>04853</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>PELHAM ART CENTER</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>155 FIFTH AVENUE</AddressLine1Txt>
#             <CityNm>PELHAM</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10803</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>PELHAM CHILDREN'S CENTER</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>20 5TH AVENUE</AddressLine1Txt>
#             <CityNm>PELHAM</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10803</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>UNION SETTLEMENT ASSOCIATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>237 EAST 104TH STREET</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10029</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>UNIVERSITY SETTLEMENT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>184 ELDRIDGE STREET</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10002</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>WAMC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>318 CENTRAL AVE</AddressLine1Txt>
#             <CityNm>ALBANY</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>12206</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>INNER-CITY SCHOLARSHIP FUND</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1011 FIRST AVE</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10022</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>NATIONAL MS SOCIETY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 4527</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10163</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>PELHAM EDUCATION FOUNDATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 8302</AddressLine1Txt>
#             <CityNm>PELHAM</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10803</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>RIP MEDICAL DEBT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>80 THEODORE FREMD AVE</AddressLine1Txt>
#             <CityNm>RYE</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10580</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>5000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CITIZENS BUDGET COMMISSION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>2 PENNSYLVANIA PLAZA</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10001</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>10000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>COOPERSTOWN CHAMBER MUSIC FESTIVAL</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 230</AddressLine1Txt>
#             <CityNm>COOPERSTOWN</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>13326</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>10000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>RORY STAUNTON FOUNDATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>135 WEST 50TH STREET EUROTECH SUITE</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10020</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>10000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>UNITED HOSPITAL FUND</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1411 BROADWAY</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10018</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>10000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>PLANNED PARENTHOOD HUDSON PECONIC INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>4 SKYLINE DR</AddressLine1Txt>
#             <CityNm>HAWTHORNE</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10532</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>15000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>WIKIMEDIA FOUNDATION INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>149 NEW MONTGOMERY STREET6TH FLOOR</AddressLine1Txt>
#             <CityNm>SAN FRANCISCO</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>94105</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>15000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>WYNC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 1550</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10116</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>15000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>AMERICAN FRIENDS OF EPISCOPAL DIOCESE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>25 OLD KINGS HWY</AddressLine1Txt>
#             <CityNm>DARIEN</CityNm>
#             <StateAbbreviationCd>CT</StateAbbreviationCd>
#             <ZIPCd>06820</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>25000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>COBSCOOK COMMUNITY LEARNING CENTER</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>10 COMMISSARY POINT ROAD</AddressLine1Txt>
#             <CityNm>LUBEC</CityNm>
#             <StateAbbreviationCd>ME</StateAbbreviationCd>
#             <ZIPCd>04652</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>25000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CAMP O-AT-KA</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 239</AddressLine1Txt>
#             <CityNm>SEBAGO</CityNm>
#             <StateAbbreviationCd>ME</StateAbbreviationCd>
#             <ZIPCd>04029</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>55000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>LASALLE ACADEMY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>215 EAST 6TH STREET</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10003</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL PURPOSES</GrantOrContributionPurposeTxt>
#           <Amt>75000</Amt>
# ...
#         </SubtotalsIncmProducingActyGrp>
#         <TotalIncomeProducingActyAmt>201612</TotalIncomeProducingActyAmt>
#       </AnalysisIncomeProducingActyGrp>
#       <TrnsfrTransRlnNonchrtblEOGrp>
#         <TrnsfrOfCashToNonchrtblEOInd>0</TrnsfrOfCashToNonchrtblEOInd>
#         <TrnsfrOtherAssetNonchrtblEOInd>0</TrnsfrOtherAssetNonchrtblEOInd>
#         <SalesOrExchangesOfAssetsInd>0</SalesOrExchangesOfAssetsInd>
#         <PurchaseOfAssetsNonchrtblEOInd>0</PurchaseOfAssetsNonchrtblEOInd>
#         <RentalOfFacilitiesOthAssetsInd>0</RentalOfFacilitiesOthAssetsInd>
#         <ReimbursementArrangementsInd>0</ReimbursementArrangementsInd>
#         <LoansOrLoanGuaranteesInd>0</LoansOrLoanGuaranteesInd>
#         <PerformanceOfServicesEtcInd>0</PerformanceOfServicesEtcInd>
#         <SharingOfFacilitiesEtcInd>0</SharingOfFacilitiesEtcInd>
#         <RelationshipsNonchrtblEOInd>0</RelationshipsNonchrtblEOInd>
#       </TrnsfrTransRlnNonchrtblEOGrp>
#     </IRS990PF>
#     <AccountingFeesSchedule documentId="RetDoc2002200001">
#       <AccountingFeesDetail>
#         <CategoryTxt>SACKS PRESS &amp; LACHER</CategoryTxt>
#         <Amt>7000</Amt>
#         <NetInvestmentIncomeAmt>7000</NetInvestmentIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </AccountingFeesDetail>
#     </AccountingFeesSchedule>
#     <InvestmentsCorpStockSchedule documentId="RetDoc2018900001">
#       <InvestmentsCorporateStockGrp>
#         <StockNm>ABBOTT LABS - 868 SHS</StockNm>
#         <EOYBookValueAmt>30968</EOYBookValueAmt>
#         <EOYFMVAmt>72999</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>ACCENTURE PLC IRELAND CL A - 265 SHS</StockNm>
#         <EOYBookValueAmt>38496</EOYBookValueAmt>
#         <EOYFMVAmt>48964</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>AIR PROD &amp; CHEMICAL INC - 285 SHS</StockNm>
#         <EOYBookValueAmt>30044</EOYBookValueAmt>
#         <EOYFMVAmt>64515</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>ALPHABET INC CL A - 87 SHS</StockNm>
#         <EOYBookValueAmt>53023</EOYBookValueAmt>
#         <EOYFMVAmt>94204</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>ALPHABET INC CL C - 28 SHS</StockNm>
#         <EOYBookValueAmt>13230</EOYBookValueAmt>
#         <EOYFMVAmt>30265</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>AMGEN INC- 56 SHS</StockNm>
#         <EOYBookValueAmt>8298</EOYBookValueAmt>
#         <EOYFMVAmt>10320</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>APPLE INC - 742 SHS</StockNm>
#         <EOYBookValueAmt>66822</EOYBookValueAmt>
#         <EOYFMVAmt>146857</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>ASTRAZENECA PLC SPON ADR - 1030 SHS</StockNm>
#         <EOYBookValueAmt>28619</EOYBookValueAmt>
#         <EOYFMVAmt>42518</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>BLACKROCK INC - 102 SHS</StockNm>
#         <EOYBookValueAmt>51342</EOYBookValueAmt>
#         <EOYFMVAmt>47869</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>BOEING COMPANY - 449 SHS</StockNm>
#         <EOYBookValueAmt>57275</EOYBookValueAmt>
#         <EOYFMVAmt>163440</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>CHEVRON CORP - 297 SHS</StockNm>
#         <EOYBookValueAmt>35662</EOYBookValueAmt>
#         <EOYFMVAmt>36959</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>COLGATE PALMOLIVE CO - 1158 SHS</StockNm>
#         <EOYBookValueAmt>72885</EOYBookValueAmt>
#         <EOYFMVAmt>82994</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>COMCAST CORP NEW CL A - 851 SHS</StockNm>
#         <EOYBookValueAmt>29650</EOYBookValueAmt>
#         <EOYFMVAmt>35980</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>CONSUMERS STAPLES SELECT SPDR 847 SHS</StockNm>
#         <EOYBookValueAmt>42943</EOYBookValueAmt>
#         <EOYFMVAmt>49185</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>CORTEVA INC 219 SHS</StockNm>
#         <EOYBookValueAmt>5336</EOYBookValueAmt>
#         <EOYFMVAmt>6476</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>CRANE CO - 1165 SHS</StockNm>
#         <EOYBookValueAmt>67150</EOYBookValueAmt>
#         <EOYFMVAmt>97208</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>DIAGEO PLC NEW GB SPON ADR - 658 SHS</StockNm>
#         <EOYBookValueAmt>74624</EOYBookValueAmt>
#         <EOYFMVAmt>113387</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>DOW INC 219 SHS</StockNm>
#         <EOYBookValueAmt>10126</EOYBookValueAmt>
#         <EOYFMVAmt>10799</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>DU PONT DE NEMOURS - 219 SHS</StockNm>
#         <EOYBookValueAmt>14709</EOYBookValueAmt>
#         <EOYFMVAmt>16440</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>EVERSOURCE ENERGY COM - 777 SHS</StockNm>
#         <EOYBookValueAmt>34398</EOYBookValueAmt>
#         <EOYFMVAmt>58866</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>GENL MILLS INC - 670 SHS</StockNm>
#         <EOYBookValueAmt>33219</EOYBookValueAmt>
#         <EOYFMVAmt>35188</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>HOME DEPOT INC - 705 SHS</StockNm>
#         <EOYBookValueAmt>68749</EOYBookValueAmt>
#         <EOYFMVAmt>146619</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>ILLINOIS TOOL WORKS INC - 783 SHS</StockNm>
#         <EOYBookValueAmt>65687</EOYBookValueAmt>
#         <EOYFMVAmt>118084</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>INTEL CORP - 2705 SHS</StockNm>
#         <EOYBookValueAmt>71145</EOYBookValueAmt>
#         <EOYFMVAmt>129488</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>JOHNSON &amp; JOHNSON COM - 365 SHS</StockNm>
#         <EOYBookValueAmt>32778</EOYBookValueAmt>
#         <EOYFMVAmt>50837</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>LOCKHEED MARTIN CORP - 35 SHS</StockNm>
#         <EOYBookValueAmt>8425</EOYBookValueAmt>
#         <EOYFMVAmt>12724</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>MCDONALDS CORP - 349 SHS</StockNm>
#         <EOYBookValueAmt>34283</EOYBookValueAmt>
#         <EOYFMVAmt>72473</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>MEDTRONIC PLC - 1106 SHS</StockNm>
#         <EOYBookValueAmt>83161</EOYBookValueAmt>
#         <EOYFMVAmt>107713</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>MICROSOFT CORP - 1355 SHS</StockNm>
#         <EOYBookValueAmt>56453</EOYBookValueAmt>
#         <EOYFMVAmt>181516</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>MONDELEZ INTL INC - 939 SHS</StockNm>
#         <EOYBookValueAmt>39461</EOYBookValueAmt>
#         <EOYFMVAmt>50612</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>NEXTERA ENERGY INC COM - 741 SHS</StockNm>
#         <EOYBookValueAmt>70970</EOYBookValueAmt>
#         <EOYFMVAmt>151801</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>NOVARTIS AG SPON ADR - 839 SHS</StockNm>
#         <EOYBookValueAmt>65146</EOYBookValueAmt>
#         <EOYFMVAmt>76609</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>PEPSICO INC - 419 SHS</StockNm>
#         <EOYBookValueAmt>39760</EOYBookValueAmt>
#         <EOYFMVAmt>54943</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>PRINCIPAL SHRT-TRM INC P - 25597 SHS</StockNm>
#         <EOYBookValueAmt>312441</EOYBookValueAmt>
#         <EOYFMVAmt>313820</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>PROCTER &amp; GAMBLE CO - 431 SHS</StockNm>
#         <EOYBookValueAmt>33860</EOYBookValueAmt>
#         <EOYFMVAmt>47259</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>PRUDENTIAL SHORT-TERM CORPORATE BOND FUND INC - 28079 SHS</StockNm>
#         <EOYBookValueAmt>313893</EOYBookValueAmt>
#         <EOYFMVAmt>310839</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>ROCKWELL AUTOMATION INC NEW - 598 SHS</StockNm>
#         <EOYBookValueAmt>67238</EOYBookValueAmt>
#         <EOYFMVAmt>97970</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>STANLEY BLACK &amp; DECKER INC COM - 427 SHS</StockNm>
#         <EOYBookValueAmt>34317</EOYBookValueAmt>
#         <EOYFMVAmt>61748</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>STRYKER CORP - 22 SHS</StockNm>
#         <EOYBookValueAmt>3433</EOYBookValueAmt>
#         <EOYFMVAmt>4523</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>TEXAS INSTRUMENTS - 826 SHS</StockNm>
#         <EOYBookValueAmt>39913</EOYBookValueAmt>
#         <EOYFMVAmt>94792</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>THORNBURG LTD TERM INCOME FUND - 32565 SHS</StockNm>
#         <EOYBookValueAmt>437662</EOYBookValueAmt>
#         <EOYFMVAmt>440925</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>TOTAL S.A. FRANCE SPON ADR - 1263 SHS</StockNm>
#         <EOYBookValueAmt>64871</EOYBookValueAmt>
#         <EOYFMVAmt>70463</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>UNILEVER PLC AMER SHS NEW SPON ADR - 865 SHS</StockNm>
#         <EOYBookValueAmt>34311</EOYBookValueAmt>
#         <EOYFMVAmt>53604</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>UNION PACIFIC CORP - 469 SHS</StockNm>
#         <EOYBookValueAmt>39722</EOYBookValueAmt>
#         <EOYFMVAmt>79313</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>UNITED PARCEL SERVICE INC CL B - 751 SHS</StockNm>
#         <EOYBookValueAmt>72592</EOYBookValueAmt>
#         <EOYFMVAmt>77556</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>UNTD TECHNOLOGIES CORP - 721 SHS</StockNm>
#         <EOYBookValueAmt>73095</EOYBookValueAmt>
#         <EOYFMVAmt>93874</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>WALT DISNEY CO - 33 SHS</StockNm>
#         <EOYBookValueAmt>3438</EOYBookValueAmt>
#         <EOYFMVAmt>4608</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>YUM! BRANDS INC - 838 SHS</StockNm>
#         <EOYBookValueAmt>46902</EOYBookValueAmt>
#         <EOYFMVAmt>92741</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#     </InvestmentsCorpStockSchedule>
#     <InvestmentsOtherSchedule2 documentId="RetDoc2018100001">
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>BROOKSIDE CAPITAL PARTNERS</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>303868</BookValueAmt>
#         <EOYFMVAmt>303868</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>MITHRIL LP</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>80947</BookValueAmt>
#         <EOYFMVAmt>80947</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>NSV EXTENSION FUND II LP</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>1329492</BookValueAmt>
#         <EOYFMVAmt>1329492</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>NSV OPPORTUNITY FUND LP</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>1442339</BookValueAmt>
#         <EOYFMVAmt>1442339</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>RAIL SPLITTER FUND</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>3707410</BookValueAmt>
#         <EOYFMVAmt>3707410</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>SC FUNDAMENTAL VALUE FUND</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>2354162</BookValueAmt>
#         <EOYFMVAmt>2354162</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#     </InvestmentsOtherSchedule2>
#     <OtherDecreasesSchedule documentId="RetDoc2049800001">
#       <OtherDecreasesDetail>
#         <Desc>UNREALIZED APPRECIATION FROM PARTNERSHIP INVESTMENTS</Desc>
#         <Amt>1133780</Amt>
#       </OtherDecreasesDetail>
#     </OtherDecreasesSchedule>
#     <OtherExpensesSchedule documentId="RetDoc2003200001">
#       <OtherExpensesScheduleGrp>
#         <Desc>FILING FEES</Desc>
#         <RevenueAndExpensesPerBooksAmt>750</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </OtherExpensesScheduleGrp>
#       <OtherExpensesScheduleGrp>
#         <Desc>K-1 PASS THRU DEDUCTIONS</Desc>
#         <RevenueAndExpensesPerBooksAmt>188852</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>187130</NetInvestmentIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </OtherExpensesScheduleGrp>
#       <OtherExpensesScheduleGrp>
#         <Desc>OFFICE EXPENSE</Desc>
#         <RevenueAndExpensesPerBooksAmt>7251</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>3751</NetInvestmentIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>3500</DisbursementsCharitablePrpsAmt>
#       </OtherExpensesScheduleGrp>
#       <OtherExpensesScheduleGrp>
#         <Desc>PROFESSIONAL SERVICES</Desc>
#         <RevenueAndExpensesPerBooksAmt>5000</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>5000</DisbursementsCharitablePrpsAmt>
#       </OtherExpensesScheduleGrp>
#     </OtherExpensesSchedule>
#     <OtherProfessionalFeesSchedule documentId="RetDoc2002300001">
#       <OtherProfessionalFeesDetail>
#         <CategoryTxt>UBS</CategoryTxt>
#         <Amt>33726</Amt>
#         <NetInvestmentIncomeAmt>33726</NetInvestmentIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </OtherProfessionalFeesDetail>
#     </OtherProfessionalFeesSchedule>
#     <TaxesSchedule documentId="RetDoc2002500001">
#       <TaxesDetail>
#         <CategoryTxt>FOREIGN TAXES WITHHELD</CategoryTxt>
#         <Amt>11300</Amt>
#         <NetInvestmentIncomeAmt>11300</NetInvestmentIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </TaxesDetail>
#     </TaxesSchedule>
#   </ReturnData>
# </Return>

# %% [markdown]
# #Retrieving 990 forms (2020)

# %%
with open('full_foundation_list_data.json', 'w') as fp:
  json.dump(matched, fp, indent = 4)

# %%
print(matched['woodward family foundation']['URL'])
# Out:
# https://s3.amazonaws.com/irs-form-990/201903159349100920_public.xml

# %%
response = requests.get(matched['woodward family foundation']['URL'])
response.status_code
# Out:
# 200

# %%
#creating 990 forms dataset
full_foundation_list_990 = {}

# %%
for k in matched:
  response = requests.get(matched[k]['URL'])
  full_foundation_list_990[k] = response.text

# %%
with open('full_foundation_list_990.json', 'w') as fp:
  json.dump(full_foundation_list_990, fp, indent = 4)

# %% [markdown]
# #Fuzzy Matching Method 1

# %% [markdown]
# ##Cleaning index dataset and identifying the most commonly used words

# %%
def clean_special_characters(txt):
  seps = [" ", ";", ":", ",", ".", "*", "#", "@", "|", "\\", "-", "_", "!", "%", "^", "(", ")"]
  default_sep = seps[0]

  for sep in seps[1:]:
    txt = txt.replace(sep, default_sep)
  #re.sub(' +', ' ', txt)
  temp_list = [i.strip() for i in txt.split(default_sep)]
  temp_list = [i for i in temp_list if i]
  return " ".join(temp_list)

def clean_stopword(txt):
  
  temp_list = txt.split(" ")
  temp_list = [i for i in temp_list if i not in stopwords]
  return " ".join(temp_list)

def data_cleaning(data, nameCol='CompanyName', dropForeign = True):   #colName for company name - create df?
  data.dropna(subset = [nameCol], inplace=True)
  #data = data.rename_axis('CompanyID').resetIndex()
  data['nonAscii_count'] = data[nameCol].apply(lambda x: sum([not c.isascii() for c in x]))
  if dropForeign:
    data=data[data.nonAscii_count==0]
  else:
    pass
  data.drop('nonAscii_count', axis=1, inplace=True)
  data_clean=data.copy()
  data_clean['Name_clean'] = data_clean[nameCol].apply(lambda x: x.lower())
  data_clean['Name_clean'] = data_clean['Name_clean'].apply(clean_special_characters)
  data_clean['Name_clean'] = data_clean['Name_clean'].apply(clean_stopword)
  return data_clean

# %% [markdown]
# ##Similarity score, Clustering similar names, Assigning Standard names, Confidence Score, White space correction

# %%
 def similarity(company_names):
  company_names = company_names.split()
  similarity_array = np.ones((len(company_names),(len(company_names))))*100

  for i in range(1, len(company_names)):
    for j in range(i):
      s1 = fuzz.token_set_ratio(company_names[i], company_names[j])+0.000000000001
      s2 = fuzz.partial_ratio(company_names[i], company_names[j]) + 0.00000000001
      similarity_array[i][j] = 2*s1*s2 / (s1+s2)
  
  for i in range(len(company_names)):
    for j in range(i+1, len(company_names)):
      similarity_array[i][j]

  np.fill_diagonal(similarity_array, 100)
  return  similarity_array


def company_clusters(data, nameCol='CompanyName', dropForeign=True):
  data_clean = data_cleaning(data, nameCol=nameCol, dropForeign=dropForeign)
  company_names = data_clean.CustomerName_clean.to_list()
  #cust_ids = data_clean.companyID.to_list()

  similarity_array = fuzz_similarity(company_names)
  clusters = cluster.AffinityPropagation(affinity='precomputed').fit_predict(similarity_array)
  df_clusters = pd.DataFrame(list(zip(cust_ids, clusters)), columns=['CompanyID', 'cluster'])

  df_eval = df_clusters.merge(data_clean, on='CompanyID', how='left')
  return df_eval

# %%
def standard_name(df_eval):
  d_standard_name={}
  for cluster in df_eval.cluster.unique():
    names = df_eval[df_eval['cluster']==cluster].CompanyName_clean.to_list()
    l_common_substring = []
    if len(names)>1:
      for i in range(0,len(names)):
        for j in range(i+1, len(names)):
          seqMatch = SequenceMatcher(None, names[i],names[j])
          match = seqMatch.find_longest_match(0, len(names[i]), 0, names[j])
          if match.size!=0:
            l_common_substring.append(names[i][match.a: match.a + match.size].strip())
    
    else:
      d_standard_name[cluster] = names[0]
  
  df_standard_names = pd.DataFrame(list(d_standard_name.items()), columns=['cluster', 'StandardName'])
  df_eval = df_eval.merge(df.standard_names, on='cluster', how='left')
  df_eval['Score_with_standard'] = df_eval.apply(lambda x: fuzz.token_set_ratio(x['StandardName'], x[CompanyName_clean]), axis=1)
  df_eval['standard_name_withoutSpaces'] = df_eval.StandardName.apply(lambda x: x.replace(' ', ''))

  for name in df_eval.standard_name_withoutSpaces.unique():
    if len(df_eval[df_eval.standard_name_withoutSpaces==name].cluster.unique()) > 1:
      df_eval.loc[df_eval.standard_name_withoutSpaces==name, 'StandardName'] = name
  
  return df_eval.drop('standard_name_withoutSpaces', axis = 1)

# %% [markdown]
# #Fuzzy Matching Method 2

# %%
#!pip3 install fuzzywuzzy
from fuzzywuzzy import fuzz

def match_name(name, list_names, min_score=0):

  #if there are no matches, return -1
  max_score = -1    
  #returning empty name if no match
  max_name=''
  for name2 in list_names:
    score = fuzz.ratio(name,name2)

    if (score>min_score) and (score>max_score):
      max_name = name2
      max_score = score
  
  return (max_name, max_score)
# Out:
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.6/dist-packages (0.18.0)

# %%
#ut_list_names = list(unmatched.keys())
ut_list_names = unmatched
ut_list_names[:10]
# Out:
# ['12th man foundation',
#  '2a foundation',
#  '4girls foundation inc.',
#  '4girls foundation incorporated',
#  '7th generation foundation',
#  '80-20 foundation',
#  'a foundation for contemporary art art pace',
#  'a g foundation',
#  'a. james & alice b. clark foundation',
#  'a. w. riterfamily foundation']

# %%
index_names = list(index.keys())
print(len(index_names))

index_dict = {}
for name in index_names:
  index_dict[name] = index[name]['URL']
# Out:
# 311244
# labor management cooperation fund https://s3.amazonaws.com/irs-form-990/202040859349200204_public.xml
# hayward softball umpires association https://s3.amazonaws.com/irs-form-990/201933189349204783_public.xml
# vda inc https://s3.amazonaws.com/irs-form-990/201933179349201508_public.xml
# sacramento stingrays swim team https://s3.amazonaws.com/irs-form-990/202002379349200860_public.xml
# pi kappa phi fraternity https://s3.amazonaws.com/irs-form-990/202040659349200109_public.xml
# epsilon upsilon corporation of alpha phi https://s3.amazonaws.com/irs-form-990/202002379349200880_public.xml
# molalla rotary club https://s3.amazonaws.com/irs-form-990/202002379349200905_public.xml
# neurovascular foundation https://s3.amazonaws.com/irs-form-990/202002379349200950_public.xml
# american board of home care https://s3.amazonaws.com/irs-form-990/202002379349201150_public.xml
# ceeds4change https://s3.amazonaws.com/irs-form-990/202022099349200127_public.xml
# new york spirit charities inc dba cheer ny https://s3.amazonaws.com/irs-form-990/202022099349200212_public.xml
# clubhouse library of c v e inc https://s3.amazonaws.com/irs-form-990/202022099349200532_public.xml
# pto thacher and elc inc https://s3.amazonaws.com/irs-form-990/202022099349200607_public.xml
# sierra rose farms healing hearts w horses foundat https://s3.amazonaws.com/irs-form-990/202022099349200617_public.xml
# associazione culturale pugliese figli maria ss addolorata inc https://s3.amazonaws.com/irs-form-990/202022099349200702_public.xml

# %%
from nltk.corpus import stopwords
from fuzzywuzzy import fuzz

def clean_stopword(txt):
  stop_words = set(stopwords.words('english'))
  extended_stopwords = set([key for key, _ in wordfreq])
  updated_stop_words = stop_words | extended_stopwords
  temp_list = txt.split(" ")
  temp_list = [i for i in temp_list if i not in updated_stop_words]
  return " ".join(temp_list)

# %%
for key in index_dict.keys():
  #index_names[i] = clean_special_characters(index_names[i])
  clean_key = clean_stopword(key)
  index_wo_stopwords_dict[clean_key] = index_dict[key]

# %%
print(index_wo_stopwords_dict['quincy arena'])
# Out:
# https://s3.amazonaws.com/irs-form-990/202030089349300923_public.xml

# %%
dict_list = []

for name2search in ut_list_names:
  match = match_name(name2search, index_names, 75)

  dict_ = {}
  dict_.update({"company name" : name2search})
  dict_.update({"match_name" : match[0]})
  dict_.update({"score" : match[1]})
  dict_list.append(dict_)

merge_table = pd.DataFrame(dict_list)
merge_table
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-49b4ec2baa6b> in <module>()
#       2
#       3 for name2search in ut_list_names:
# ----> 4   match = match_name(name2search, index_names, 75)
#       5
#       6   dict_ = {}
#
# <ipython-input-37-8860fdbdf167> in match_name(name, list_names, min_score)
#       9   max_name=''
#      10   for name2 in list_names:
# ---> 11     score = fuzz.ratio(name,name2)
#      12
#      13     if (score>min_score) and (score>max_score):
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      27         if args[0] == args[1]:
#      28             return 100
# ---> 29         return func(*args, **kwargs)
#      30     return decorator
#      31
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      45         if len(args[0]) == 0 or len(args[1]) == 0:
#      46             return 0
# ---> 47         return func(*args, **kwargs)
#      48     return decorator
#      49
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py in ratio(s1, s2)
#      26
#      27     m = SequenceMatcher(None, s1, s2)
# ---> 28     return utils.intr(100 * m.ratio())
#      29
#      30
#
# /usr/lib/python3.6/difflib.py in ratio(self)
#     642         """
#     643
# --> 644         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     645         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     646
#
# /usr/lib/python3.6/difflib.py in get_matching_blocks(self)
#     512
#     513         non_adjacent.append( (la, lb, 0) )
# --> 514         self.matching_blocks = list(map(Match._make, non_adjacent))
#     515         return self.matching_blocks
#     516
#
# <string> in _make(cls, iterable, new, len)
#
# KeyboardInterrupt:

# %%
merge_table = pd.DataFrame(dict_list)
merge_table
# Out:
#                      company name                     match_name  score
# 0             12th man foundation               hyman foundation     86
# 1                   2a foundation                  l2 foundation     92
# 2          4girls foundation inc.            grhs foundation inc     88
# 3  4girls foundation incorporated  smile foundation incorporated     88
# 4       7th generation foundation     next generation foundation     90
# 5                80-20 foundation                 300 foundation     87

# %% [markdown]
# #Fuzzy Matching Method 3

# %%
from collections import Counter

index_names = list(index.keys())
listToStr_unmatched = ' '.join(map(str, unmatched))
listToStr_index = ' '.join(map(str, index_names))

listToStr = listToStr_unmatched + ' ' + listToStr_index

wordlist = listToStr.split()

wordfreq = Counter(wordlist).most_common(100)
#print wordfreq.most_common(20)

# %%
index_wo_stopwords_dict = {}

# %%
print(wordfreq)
# Out:
# [('inc', 121787), ('of', 54629), ('foundation', 51732), ('association', 27572), ('and', 27331), ('club', 15404), ('for', 14915), ('center', 14272), ('county', 12529), ('community', 11511), ('the', 10579), ('school', 9691), ('family', 8917), ('fund', 8267), ('co', 7810), ('society', 7281), ('american', 6652), ('international', 6503), ('corporation', 6457), ('health', 6426), ('trust', 6308), ('new', 5375), ('education', 5223), ('housing', 5217), ('services', 5165), ('council', 5086), ('development', 5049), ('fire', 4594), ('ministries', 4293), ('charitable', 4252), ('youth', 4234), ('local', 4086), ('friends', 3803), ('valley', 3801), ('institute', 3660), ('union', 3602), ('care', 3573), ('area', 3474), ('academy', 3432), ('chamber', 3411), ('national', 3375), ('league', 3287), ('in', 3249), ('chapter', 3207), ('united', 3141), ('north', 3117), ('st', 3099), ('a', 3017), ('rotary', 3014), ('volunteer', 3004), ('company', 2978), ('medical', 2973), ('commerce', 2959), ('assoc', 2920), ('christian', 2870), ('arts', 2858), ('home', 2843), ('memorial', 2837), ('alliance', 2814), ('house', 2659), ('corp', 2557), ('city', 2500), ('america', 2429), ('rescue', 2355), ('state', 2354), ('high', 2325), ('greater', 2301), ('project', 2289), ('south', 2275), ('central', 2262), ('hospital', 2251), ('hope', 2245), ('-', 2231), ('california', 2204), ('post', 2137), ('childrens', 2134), ('dba', 2134), ('pta', 2108), ('college', 2097), ('senior', 2077), ('public', 2067), ('group', 2026), ('university', 2021), ('research', 1985), ('park', 1973), ('texas', 1970), ('west', 1965), ('elementary', 1947), ('san', 1911), ('life', 1900), ('department', 1882), ('museum', 1869), ('network', 1865), ('educational', 1848), ('water', 1847), ('library', 1818), ('lake', 1804), ('york', 1793), ('scholarship', 1762), ('no', 1706)]

# %%
from google.colab import files
# !pip3 install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading https://files.pythonhosted.org/packages/43/ff/74f23998ad2f93b945c0309f825be92e04e0348e062026998b5eefef4c33/fuzzywuzzy-0.18.0-py2.py3-none-any.whl
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
from nltk.corpus import stopwords
from fuzzywuzzy import fuzz

def clean_special_characters(txt):
  seps = [" ", ";", ":", ",", ".", "*", "#", "@", "|", "\\", "-", "_", "!", "%", "^", "(", ")"]
  default_sep = seps[0]
  for sep in seps[1:]:
    txt = txt.replace(sep, default_sep)
  #re.sub(' +', ' ', txt)
  temp_list = [i.strip() for i in txt.split(default_sep)]
  temp_list = [i for i in temp_list if i]
  return " ".join(temp_list)


def clean_stopword(txt):
  stop_words = set(stopwords.words('english'))
  extended_stopwords = set([key for key, _ in wordfreq])
  updated_stop_words = stop_words | extended_stopwords
  temp_list = txt.split(" ")
  temp_list = [i for i in temp_list if i not in updated_stop_words]
  return " ".join(temp_list)


def match_name(name, list_names, min_score=0):

  #if there are no matches, return -1
  max_score = -1    
  #returning empty name if no match
  max_name=''
  for name2 in list_names:
    score = fuzz.token_set_ratio(name,name2)
    if (score>min_score) and (score>max_score):
      max_name = name2
      max_score = score
  return (max_name, max_score)


ut_list_names = unmatched
index_names = list(index.keys())
for i in range(len(ut_list_names)):
  #ut_list_names[i] = clean_special_characters(ut_list_names[i])
  ut_list_names[i] = clean_stopword(ut_list_names[i])

for key in index_dict.keys():
  #index_names[i] = clean_special_characters(index_names[i])
  clean_key = clean_stopword(key)
  index_wo_stopwords_dict[clean_key] = index_dict[key]

dict_list = []
merge_table = pd.DataFrame()
flag=0
for name2search in ut_list_names:
  match = match_name(name2search, index_names, 75)
  if(flag%100==0):
    print(flag)
  flag+=1
  dict_ = {}
  dict_.update({"company name" : name2search})
  dict_.update({"match_name" : match[0]})
  dict_.update({"score" : match[1]})
  dict_list.append(dict_)
  merge_table.append(dict_list, ignore_index = True)


merge_table.to_csv('merge_table.csv', sep='\t', encoding='utf-8')
files.download('merge_table.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# 0
# 100
# 200
# 300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-17d049160949> in <module>()
#      50 flag=0
#      51 for name2search in ut_list_names:
# ---> 52   match = match_name(name2search, index_names, 75)
#      53   if(flag%100==0):
#      54     print(flag)
#
# <ipython-input-24-17d049160949> in match_name(name, list_names, min_score)
#      29   max_name=''
#      30   for name2 in list_names:
# ---> 31     score = fuzz.token_set_ratio(name,name2)
#      32     if (score>min_score) and (score>max_score):
#      33       max_name = name2
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py in token_set_ratio(s1, s2, force_ascii, full_process)
#     167
#     168 def token_set_ratio(s1, s2, force_ascii=True, full_process=True):
# --> 169     return _token_set(s1, s2, partial=False, force_ascii=force_ascii, full_process=full_process)
#     170
#     171
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py in _token_set(s1, s2, partial, force_ascii, full_process)
#     161         ratio_func(sorted_sect, combined_1to2),
#     162         ratio_func(sorted_sect, combined_2to1),
# --> 163         ratio_func(combined_1to2, combined_2to1)
#     164     ]
#     165     return max(pairwise)
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      27         if args[0] == args[1]:
#      28             return 100
# ---> 29         return func(*args, **kwargs)
#      30     return decorator
#      31
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      45         if len(args[0]) == 0 or len(args[1]) == 0:
#      46             return 0
# ---> 47         return func(*args, **kwargs)
#      48     return decorator
#      49
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py in ratio(s1, s2)
#      26
#      27     m = SequenceMatcher(None, s1, s2)
# ---> 28     return utils.intr(100 * m.ratio())
#      29
#      30
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in intr(n)
#     101
#     102
# --> 103 def intr(n):
#     104     '''Returns a correctly rounded integer'''
#     105     return int(round(n))
#
# KeyboardInterrupt:

# %%
print(dict_list)
# Out:
# [{'company name': '12th man', 'match_name': 'crosses 12th man', 'score': 100}, {'company name': '2a', 'match_name': 'geshe tsulga non-profit sera je 2a monks affil', 'score': 100}, {'company name': '4girls inc.', 'match_name': 'girls 4 science', 'score': 80}, {'company name': '4girls incorporated', 'match_name': 'incorporated', 'score': 100}, {'company name': '7th generation', 'match_name': 'generation', 'score': 100}, {'company name': '80-20', 'match_name': '20', 'score': 100}, {'company name': 'contemporary art art pace', 'match_name': 'pace', 'score': 100}, {'company name': 'g', 'match_name': 'p g', 'score': 100}, {'company name': 'a. james & alice b. clark', 'match_name': 'clark', 'score': 100}, {'company name': 'a. w. riterfamily', 'match_name': 'w', 'score': 100}, {'company name': 'a.i. manet schepps', 'match_name': 'manet', 'score': 100}, {'company name': 'a.i. manet schepps inc.', 'match_name': 'manet', 'score': 100}, {'company name': 'aaaa inc.', 'match_name': 'aaaa', 'score': 100}, {'company name': 'aatcc', 'match_name': 'aatcc', 'score': 100}, {'company name': 'abbott leslie sprague', 'match_name': 'leslie', 'score': 100}, {'company name': 'abe zale', 'match_name': '', 'score': -1}, {'company name': 'abim', 'match_name': 'aim', 'score': 86}, {'company name': 'nutrition & dietetics', 'match_name': 'nutrition dietetics', 'score': 100}, {'company name': 'accesslex', 'match_name': 'accessible', 'score': 84}, {'company name': 'achelis & bodman foundations', 'match_name': 'bodman', 'score': 100}, {'company name': 'aci', 'match_name': 'eastern pa de aci', 'score': 100}, {'company name': 'aclu', 'match_name': 'aclu colorado', 'score': 100}, {'company name': 'adam f & celia staperfene', 'match_name': 'adam', 'score': 100}, {'company name': 'adams inc.', 'match_name': 'adams', 'score': 100}, {'company name': 'adelson', 'match_name': 'dr miriam sheldon g adelson campus jewish', 'score': 100}, {'company name': 'adolph coors', 'match_name': 'randolph scholars', 'score': 76}, {'company name': 'advertising houston', 'match_name': 'houston', 'score': 100}, {'company name': 'aetna inc.', 'match_name': 'quincy arena', 'score': 76}, {'company name': 'agee', 'match_name': 'mount zion land ii deshea agee', 'score': 100}, {'company name': 'aggregates tech rsrch & educ', 'match_name': 'tech', 'score': 100}, {'company name': 'aging mind', 'match_name': 'aging', 'score': 100}, {'company name': 'agnes marshall walker', 'match_name': 'marshall', 'score': 100}, {'company name': 'ahetems', 'match_name': 'athletes', 'score': 80}, {'company name': 'albert ethel herzstein fdn.', 'match_name': 'fdn', 'score': 100}, {'company name': 'albert w. clemmie a. caster', 'match_name': 'w', 'score': 100}, {'company name': 'alcoholic beverage fdn.', 'match_name': 'fdn', 'score': 100}, {'company name': 'alec rhodes', 'match_name': 'rhodes rhodes', 'score': 100}, {'company name': 'alex kim smith', 'match_name': 'smith', 'score': 100}, {'company name': 'alexia', 'match_name': 'alexia manor', 'score': 100}, {'company name': 'alfa', 'match_name': 'alfa residential rehab counseling', 'score': 100}, {'company name': 'alfred p. sloan', 'match_name': 'p', 'score': 100}, {'company name': 'alfred t. stanley', 'match_name': 'stanley', 'score': 100}, {'company name': 'alice c. tyler perpetual', 'match_name': 'tyler', 'score': 100}, {'company name': 'alice kleberg reynolds', 'match_name': 'reynolds', 'score': 100}, {'company name': 'alice taylor gray', 'match_name': 'gray', 'score': 100}, {'company name': 'alice v. & dave h. morris', 'match_name': 'morris', 'score': 100}, {'company name': 'football fnd & hall honor', 'match_name': 'hall', 'score': 100}, {'company name': 'allan c. gloria g. king', 'match_name': 'g c', 'score': 100}, {'company name': 'allied jewish federation colorado', 'match_name': 'colorado', 'score': 100}, {'company name': 'alpha-1', 'match_name': '1', 'score': 100}, {'company name': 'alphawood', 'match_name': '', 'score': -1}, {'company name': 'alternat ...

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import requests # Getting Webpage content
from bs4 import BeautifulSoup as bs # Scraping webpages
import json
import nltk
nltk.download()
from collections import Counter
from nltk.corpus import stopwords
from fuzzywuzzy import fuzz

#full foundation list
full_foundation_list = pd.read_csv('UT Full Foundation List .csv')
full_foundation_list.head()

full_foundation_list=full_foundation_list.astype(str)

#downloading 2020 index
# Using requests module for downloading webpage content
response2020 = requests.get('https://s3.amazonaws.com/irs-form-990/index_2020.json')
# Getting status of the request
# 200 status code means our request was successful
# 404 status code means that the resource you were looking for was not found
response2020.status_code

# Parsing html data using BeautifulSoup
soup2020 = bs(response2020.content, 'html.parser')

#Saving 990 index files as txt files for 990 returns 2020

f=open('index_2020.txt', 'w')
f.write(str(soup2020))
f.close()

#Saving summaries of 990 files (from index files) 2020
data_2020=''
summary_2020=''
with open('index_2020.txt') as json_file: 
    data_2020 = json.load(json_file)
summary_2020 = data_2020['Filings2020']
print(len(summary_2020))

index = dict()

for entry in data_2020['Filings2020']:
  name = entry['OrganizationName'].lower()
  index[name] = entry

matched = dict()
unmatched = []

for row in full_foundation_list['NAME']:
  row = row.lower()
  keys = index.keys()
  if row in keys:
    matched[row] = index[row]
  else:
    unmatched.append(row)

index_names = list(index.keys())
print(len(index_names))

index_dict = {}
for name in index_names:
  index_dict[name] = index[name]['URL']


#creating stopword list


index_names = list(index.keys())
listToStr_unmatched = ' '.join(map(str, unmatched))
listToStr_index = ' '.join(map(str, index_names))

listToStr = listToStr_unmatched + ' ' + listToStr_index

wordlist = listToStr.split()

wordfreq = Counter(wordlist).most_common(100)
#print wordfreq.most_common(20)

index_wo_stopwords_dict = {}

#cleaning stopwords
def clean_stopword(txt):
  stop_words = set(stopwords.words('english'))
  extended_stopwords = set([key for key, _ in wordfreq])
  updated_stop_words = stop_words | extended_stopwords
  temp_list = txt.split(" ")
  temp_list = [i for i in temp_list if i not in updated_stop_words]
  return " ".join(temp_list)

#fuzzy matching
def match_name(name, list_names, min_score=0):

  #if there are no matches, return -1
  max_score = -1    
  #returning empty name if no match
  max_name=''
  for name2 in list_names:
    score = fuzz.token_set_ratio(name,name2)
    if (score>min_score) and (score>max_score):
      max_name = name2
      max_score = score
  return (max_name, max_score)

ut_list_names = unmatched
index_names = list(index.keys())
for i in range(len(ut_list_names)):
  ut_list_names[i] = clean_stopword(ut_list_names[i])

index_names=[]
for key in index_dict.keys():
  clean_key = clean_stopword(key)
  index_names.append(clean_key)
  index_wo_stopwords_dict[clean_key] = index_dict[key]

dict_list = []

merge_table = pd.DataFrame()
flag=0
ctr = 1
#ut_list_names_RD = ut_list_names[1100:]
for name2search in ut_list_names:
  match = match_name(name2search, index_names, 75)
  if(flag%2==0):
    merge_table = merge_table.append(dict_list, ignore_index = True)
    dict_list = []
    fname = 'merge_table_'+str(ctr)+'.csv'
    merge_table.to_csv(fname, sep='\t', encoding='utf-8')
    # !cp $fname "/content/drive/My Drive/"
    ctr+=1
  if(flag%5==0):
    break
  flag+=1
  dict_ = {}
  dict_.update({"company name" : name2search})
  dict_.update({"match_name" : match[0]})
  dict_.update({"score" : match[1]})
  dict_.update({"URL" : index_wo_stopwords_dict[match[0]]})
  dict_list.append(dict_)

fname = 'merge_table_'+str(ctr)+'.csv'
merge_table = merge_table.append(dict_list, ignore_index = True)
merge_table.to_csv('merge_table_'+str(ctr)+'.csv', sep='\t', encoding='utf-8')
# !cp $fname.csv "/content/drive/My Drive/"
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# 333722
# 311244
# cp: cannot stat '.csv': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(dict_)
# Out:
# {'company name': '4girls incorporated', 'match_name': 'incorporated', 'score': 100, 'URL': 'https://s3.amazonaws.com/irs-form-990/202000989349301115_public.xml'}

# %% [markdown]
# #Matched data analysis and 990 retrieval

# %%
fuzzy_df = pd.read_csv('merge_table.csv', sep='\\t')
fuzzy_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#     "  ...                                               URL"
# 0  "0  ...  https://s3.amazonaws.com/irs-form-990/20202153...
# 1  "1  ...  https://s3.amazonaws.com/irs-form-990/20203231...
# 2  "2  ...  https://s3.amazonaws.com/irs-form-990/20191315...
# 3  "3  ...  https://s3.amazonaws.com/irs-form-990/20200098...
# 4  "4  ...  https://s3.amazonaws.com/irs-form-990/20204136...
#
# [5 rows x 5 columns]

# %%
name1, name2, url = [], [], []

for index, row in fuzzy_df.iterrows():  
  if row['score']==100:
    name1.append(str(row['company name']))
    name2.append(str(row['match_name']))
    url.append(str(row['URL"']))

# %% [markdown]
# ##Extracting perfect name matches (after removing stopwords) first

# %%
perfect_match_name = []
perfect_match_url = []

for i in range(len(name1)):
  if (name1[i] == name2[i]):
    perfect_match_name.append(name1[i])
    perfect_match_url.append(url[i])

print(len(perfect_match_url))
# Out:
# 123

# %%
print(perfect_match_name)
# Out:
# ['aatcc', 'alturas', 'honda', 'psychological', 'scandinavian', 'anthem', 'around table', 'barstow', 'bmi', 'bob woodruff', 'buckingham', 'bybee', 'casten', 'chartwell', 'colonial', 'greensboro', 'greenville', 'con mi madre', 'curepsp', 'direct selling', 'farris', 'applied molecular evolution', 'fraxa', 'friedman', 'paisano', 'homebuilding', 'horns giving back', 'ifpda', 'inti raymi', 'ironman', 'jacobs', 'jail', 'jem', 'jonas philanthropies', 'kleinheinz', 'kosberg', 'lebowitz', 'linbeck', 'lumina', 'march dimes', 'marchbanks', 'massage therapy', 'mcbride', 'mcneill', 'micah 6 austin', 'mpower', 'speaks', 'cmv', 'parsa', 'presbyterian', 'rhode island', 'saxena', 'scaife', 'sharedimpact', 'sobrato', 'presbyterian', 'presbyterian', 'acord', 'algae', 'bettis', 'billfish', 'bloom', 'carlson', 'chinati', 'clinton', 'cockrell', 'convergence', 'dayspring', 'douglass', 'eva marvin womack', 'favrot', 'fentress', 'gailo', 'gaither', 'gatewood', 'gill', 'goodell', 'greehey', 'hammack', 'hazelwood', 'herbert johanna liebscher', 'hildebrand', 'humphreys', 'jpb', 'kavli', 'kiran bavikatte', 'kwan', 'lazarus', 'levant', 'longevity', 'lynch', 'meinig', 'membery', 'naths', 'naths', 'neil carolyn desena', 'ney', 'notley', 'pablove', 'paulos', 'plumsock', 'pollination', 'prentiss', 'priddy', 'agenda', 'quell', 'radoff', 'roger clemens', 'rwm', 'sapphire', 'sarofim', 'sooch', 'starr', 'tolleson', 'trull', 'georgia', 'mississippi', 'waggoners', 'webber', 'trellis', 'connecticut', 'fine', 'valhalla']
